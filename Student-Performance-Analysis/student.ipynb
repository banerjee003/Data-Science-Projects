# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('student_performance.csv')

# %%
df.head()
# Out:
#    student_id  gender  study_hours  sleep_hours  attendance  internet_hours  \
# 0           1    Male            7            4          98               6
# 1           2  Female            1            8          73               5
# 2           3    Male            4            7          90               2
# 3           4    Male            4            5          64               5
# 4           5    Male            5            4          94               6
#
#    previous_grade parent_education  exam_score
# 0              50    Post Graduate       44.20
# 1              75    Post Graduate       40.00
# 2              63         Graduate       41.95
# 3              87      High School       40.00
# 4              86    Post Graduate       40.00

# %%
df.shape
# Out:
# (200, 9)
