# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('googleplaystore.csv')

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Rating            1474
# Current Ver          8
# Android Ver          3
# Type                 1
# Content Rating       1
# App                  0
# Category             0
# Reviews              0
# Size                 0
# Installs             0
# Price                0
# Genres               0
# Last Updated         0
# dtype: int64

# %%
df['Rating'].fillna(df['Rating'].mean,inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10136\439939991.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<bound method Series.mean of 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10836    4.5
# 10837    5.0
# 10838    NaN
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 10841, dtype: float64>' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df['Rating'].fillna(df['Rating'].mean,inplace=True)

# %%
df['Rating'].isna().sum()
# Out:
# np.int64(0)

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#                                                  App        Category Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN    4.1
# 1                                Coloring book moana  ART_AND_DESIGN    3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN    4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN    4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN    4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.head(10)
# Out:
#                                                  App        Category Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN    4.1
# 1                                Coloring book moana  ART_AND_DESIGN    3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN    4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN    4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN    4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN    4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN    3.8
# 7                                   Infinite Painter  ART_AND_DESIGN    4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN    4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN    4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# ...

# %%
df.isna().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
df.loc[df['Reviews'].astype(str).str.contains('M')]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
pd.to_numeric(df['Reviews'])
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10836        38
# 10837         4
# 10838         3
# 10839       114
# 10840    398307
# Name: Reviews, Length: 10829, dtype: int64

# %%
df.head(500)[df.head(500)['App'].duplicated(keep=False)].sort_values(by='App',ascending=False).head(10)
# Out:
#                                App       Category Rating  Reviews  \
# 261      join.me - Simple Meetings       BUSINESS    4.0     6989
# 282      join.me - Simple Meetings       BUSINESS    4.0     6989
# 253      join.me - Simple Meetings       BUSINESS    4.0     6989
# 347  imo free video calls and chat  COMMUNICATION    4.3  4785892
# 383  imo free video calls and chat  COMMUNICATION    4.3  4785988
# 465  imo free video calls and chat  COMMUNICATION    4.3  4785988
# 389      free video calls and chat  COMMUNICATION    4.2   594728
# 466      free video calls and chat  COMMUNICATION    4.2   594728
# 237                       Zenefits       BUSINESS    4.2      296
# 266                       Zenefits       BUSINESS    4.2      296
#
#                    Size      Installs  Type Price Content Rating  \
# 261  Varies with device    1,000,000+  Free     0       Everyone
# 282  Varies with device    1,000,000+  Free     0       Everyone
# ...

# %%
df.loc[df.duplicated(subset='App',keep=False)].sort_values(by='App')
# Out:
#                                  App            Category Rating Reviews  \
# 1393           10 Best Foods for You  HEALTH_AND_FITNESS    4.0    2490
# 1407           10 Best Foods for You  HEALTH_AND_FITNESS    4.0    2490
# 2543      1800 Contacts - Lens Store             MEDICAL    4.7   23160
# 2322      1800 Contacts - Lens Store             MEDICAL    4.7   23160
# 2385      2017 EMRA Antibiotic Guide             MEDICAL    4.4      12
# ...                              ...                 ...    ...     ...
# 3202        trivago: Hotels & Travel    TRAVEL_AND_LOCAL    4.2  219848
# 3118        trivago: Hotels & Travel    TRAVEL_AND_LOCAL    4.2  219848
# 3103        trivago: Hotels & Travel    TRAVEL_AND_LOCAL    4.2  219848
# 8291  wetter.com - Weather and Radar             WEATHER    4.2  189310
# 3652  wetter.com - Weather and Radar             WEATHER    4.2  189313
#
#                     Size     Installs  Type   Price Content Rating  \
# ...

# %%
df.head()
# Out:
#                                                  App        Category Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN    4.1
# 1                                Coloring book moana  ART_AND_DESIGN    3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN    4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN    4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN    4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.loc[df['App'].duplicated(keep=False)].sort_values(by='App').head(30)
# Out:
#                                         App            Category Rating  \
# 1393                  10 Best Foods for You  HEALTH_AND_FITNESS    4.0
# 1407                  10 Best Foods for You  HEALTH_AND_FITNESS    4.0
# 2543             1800 Contacts - Lens Store             MEDICAL    4.7
# 2322             1800 Contacts - Lens Store             MEDICAL    4.7
# 2385             2017 EMRA Antibiotic Guide             MEDICAL    4.4
# 2256             2017 EMRA Antibiotic Guide             MEDICAL    4.4
# 1337           21-Day Meditation Experience  HEALTH_AND_FITNESS    4.4
# 1434           21-Day Meditation Experience  HEALTH_AND_FITNESS    4.4
# 3083                365Scores - Live Scores              SPORTS    4.6
# 5415                365Scores - Live Scores              SPORTS    4.6
# 7035                 420 BZ Budeze Delivery             MEDICAL    5.0
# 2522                 420 BZ Budeze Delivery             MEDICAL    5.0
# ...

# %%
# # df.drop_duplicates(subset=['App'],keep='last',inplace=True)
# df['Reviews'] = pd.to_numeric(df['Reviews'], errors='coerce')
# df = df.sort_values(by='Reviews').drop_duplicates(subset='App', keep='last')

# %%
df.head()
# Out:
#                                                  App        Category Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN    4.1
# 1                                Coloring book moana  ART_AND_DESIGN    3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN    4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN    4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN    4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df['Category'].value_counts()
# Out:
# Category
# FAMILY                 1968
# GAME                   1144
# TOOLS                   841
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         390
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     230
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       84
# WEATHER                  82
# EVENTS                   64
# ART_AND_DESIGN           64
# PARENTING                60
# COMICS                   60
# ...

# %%
df['Category'] = df['Category'].str.replace('_',' ')
df['Category'] = df['Category'].str.capitalize()

# %%
df['Category'].value_counts()
# Out:
# Category
# Family                 1968
# Game                   1144
# Tools                   841
# Medical                 463
# Business                460
# Productivity            424
# Personalization         390
# Communication           387
# Sports                  384
# Lifestyle               382
# Finance                 366
# Health and fitness      341
# Photography             335
# Social                  295
# News and magazines      283
# Shopping                260
# Travel and local        258
# Dating                  234
# Books and reference     230
# Video players           175
# Education               156
# Entertainment           149
# Maps and navigation     137
# Food and drink          127
# House and home           88
# Auto and vehicles        85
# Libraries and demo       84
# Weather                  82
# Events                   64
# Art and design           64
# Parenting                60
# Comics                   60
# ...

# %%
df['Installs'].value_counts()
# Out:
# Installs
# 1,000,000+        1578
# 10,000,000+       1252
# 100,000+          1169
# 10,000+           1052
# 1,000+             905
# 5,000,000+         752
# 100+               718
# 500,000+           538
# 50,000+            478
# 5,000+             476
# 100,000,000+       409
# 10+                385
# 500+               330
# 50,000,000+        289
# 50+                205
# 5+                  82
# 500,000,000+        72
# 1+                  67
# 1,000,000,000+      58
# 0+                  14
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                                                  App        Category Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  Art and design    4.1
# 1                                Coloring book moana  Art and design    3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  Art and design    4.7
# 3                              Sketch - Draw & Paint  Art and design    4.5
# 4              Pixel Draw - Number Art Coloring Book  Art and design    4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df['Installs'] = df['Installs'].str.replace('+','').str.replace(',','')
df['Installs']
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10836        5000
# 10837         100
# 10838        1000
# 10839        1000
# 10840    10000000
# Name: Installs, Length: 10829, dtype: object

# %%
type(df.iloc[0]['Installs'])
# Out:
# str

# %%
df['Installs'] = pd.to_numeric(df['Installs'])

# %%
df.head()
# Out:
#                                                  App        Category Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  Art and design    4.1
# 1                                Coloring book moana  Art and design    3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  Art and design    4.7
# 3                              Sketch - Draw & Paint  Art and design    4.5
# 4              Pixel Draw - Number Art Coloring Book  Art and design    4.3
#
#   Reviews  Size  Installs  Type Price Content Rating  \
# 0     159   19M     10000  Free     0       Everyone
# 1     967   14M    500000  Free     0       Everyone
# 2   87510  8.7M   5000000  Free     0       Everyone
# 3  215644   25M  50000000  Free     0           Teen
# 4     967  2.8M    100000  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
type(df.iloc[0]['Installs'])
# Out:
# numpy.int64

# %%
df['Size'].value_counts()
# Out:
# Size
# Varies with device    1694
# 11M                    197
# 12M                    196
# 14M                    193
# 13M                    191
#                       ...
# 430k                     1
# 429k                     1
# 200k                     1
# 460k                     1
# 619k                     1
# Name: count, Length: 457, dtype: int64

# %%
df['Size'] = df['Size'].str.replace('Varies with device','0')

# %%
df['Size'].value_counts()
# Out:
# Size
# 0       1694
# 11M      197
# 12M      196
# 14M      193
# 13M      191
#         ...
# 430k       1
# 429k       1
# 200k       1
# 460k       1
# 619k       1
# Name: count, Length: 457, dtype: int64

# %%
df.loc[df['Size'].str.contains('k'),'Size'] = (pd.to_numeric(df.loc[df['Size'].str.contains('k'),'Size'].str.replace('k',''))*1024).astype('str')
df.loc[df['Size'].str.contains('M'),'Size'] = (pd.to_numeric(df.loc[df['Size'].str.contains('M'),'Size'].str.replace('M',''))*1024*1024).astype('str')

# %%
df['Size'].value_counts()
# Out:
# Size
# 0             1694
# 11534336.0     197
# 12582912.0     196
# 14680064.0     193
# 13631488.0     191
#               ...
# 440320.0         1
# 439296.0         1
# 204800.0         1
# 471040.0         1
# 633856.0         1
# Name: count, Length: 456, dtype: int64

# %%
df.head()
# Out:
#                                                  App        Category Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  Art and design    4.1
# 1                                Coloring book moana  Art and design    3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  Art and design    4.7
# 3                              Sketch - Draw & Paint  Art and design    4.5
# 4              Pixel Draw - Number Art Coloring Book  Art and design    4.3
#
#   Reviews        Size  Installs  Type Price Content Rating  \
# 0     159  19922944.0     10000  Free     0       Everyone
# 1     967  14680064.0    500000  Free     0       Everyone
# 2   87510   9122611.2   5000000  Free     0       Everyone
# 3  215644  26214400.0  50000000  Free     0           Teen
# 4     967   2936012.8    100000  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df['Size'] = pd.to_numeric(df['Size'])

# %%
df['Size'].dtype
# Out:
# dtype('float64')

# %%
df.head()
# Out:
#                                                  App        Category Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  Art and design    4.1
# 1                                Coloring book moana  Art and design    3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  Art and design    4.7
# 3                              Sketch - Draw & Paint  Art and design    4.5
# 4              Pixel Draw - Number Art Coloring Book  Art and design    4.3
#
#   Reviews        Size  Installs  Type Price Content Rating  \
# 0     159  19922944.0     10000  Free     0       Everyone
# 1     967  14680064.0    500000  Free     0       Everyone
# 2   87510   9122611.2   5000000  Free     0       Everyone
# 3  215644  26214400.0  50000000  Free     0           Teen
# 4     967   2936012.8    100000  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df_copy = df.copy()

# %%
df_copy.head()
# Out:
#                                                  App        Category Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  Art and design    4.1
# 1                                Coloring book moana  Art and design    3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  Art and design    4.7
# 3                              Sketch - Draw & Paint  Art and design    4.5
# 4              Pixel Draw - Number Art Coloring Book  Art and design    4.3
#
#   Reviews        Size  Installs  Type Price Content Rating  \
# 0     159  19922944.0     10000  Free     0       Everyone
# 1     967  14680064.0    500000  Free     0       Everyone
# 2   87510   9122611.2   5000000  Free     0       Everyone
# 3  215644  26214400.0  50000000  Free     0           Teen
# 4     967   2936012.8    100000  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# # Step 1: Ensure Reviews is numeric
# #df_copy['Reviews'] = pd.to_numeric(df_copy['Reviews'], errors='coerce')

# # Step 2: Keep only the row with highest reviews per App
# df_copy = df_copy.loc[df_copy.groupby('App')['Reviews'].idxmax()]

# # Step 3: Reset index
# df_copy = df_copy.reset_index(drop=True)

# # Step 4: Force clean rebuild (prevents recursion/display bugs)
# df_copy = pd.DataFrame(df_copy.values, columns=df_copy.columns)

# # Step 5: Check result
# df_copy.head()

# %%
#df_copy['App'].duplicated().sum()

# %%
#df_copy.iloc[0]

# %%
df.head()
# Out:
#                                                  App        Category Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  Art and design    4.1
# 1                                Coloring book moana  Art and design    3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  Art and design    4.7
# 3                              Sketch - Draw & Paint  Art and design    4.5
# 4              Pixel Draw - Number Art Coloring Book  Art and design    4.3
#
#   Reviews        Size  Installs  Type Price Content Rating  \
# 0     159  19922944.0     10000  Free     0       Everyone
# 1     967  14680064.0    500000  Free     0       Everyone
# 2   87510   9122611.2   5000000  Free     0       Everyone
# 3  215644  26214400.0  50000000  Free     0           Teen
# 4     967   2936012.8    100000  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df['Price'].value_counts()
# Out:
# Price
# 0         10032
# $0.99       146
# $2.99       129
# $1.99        73
# $4.99        72
#           ...
# $19.90        1
# $1.75         1
# $14.00        1
# $4.85         1
# $1.04         1
# Name: count, Length: 92, dtype: int64

# %%
[df['Price'].str.replace('$','')]
# Out:
# [0        0
#  1        0
#  2        0
#  3        0
#  4        0
#          ..
#  10836    0
#  10837    0
#  10838    0
#  10839    0
#  10840    0
#  Name: Price, Length: 10829, dtype: object]

# %%
df.loc[df['Price'].astype(str).str.contains('\$', regex=False)]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df.loc[df['Price'].str.contains(',')]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df['Price'].value_counts()
# Out:
# Price
# 0         10032
# $0.99       146
# $2.99       129
# $1.99        73
# $4.99        72
#           ...
# $19.90        1
# $1.75         1
# $14.00        1
# $4.85         1
# $1.04         1
# Name: count, Length: 92, dtype: int64

# %%
df['Price'].astype('str')
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10836    0
# 10837    0
# 10838    0
# 10839    0
# 10840    0
# Name: Price, Length: 10829, dtype: object

# %%
df['Price'].dtype
# Out:
# dtype('O')

# %%
df['Price'].value_counts()
# Out:
# Price
# 0         10032
# $0.99       146
# $2.99       129
# $1.99        73
# $4.99        72
#           ...
# $19.90        1
# $1.75         1
# $14.00        1
# $4.85         1
# $1.04         1
# Name: count, Length: 92, dtype: int64

# %%
df['Price'] = pd.to_numeric(df['Price'].str.replace('$',''))

# %%
df['Price'].dtype
# Out:
# dtype('float64')

# %%
df.loc[(df['Type'] == 'Free') & (df['Price'] != 0)]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df.loc[df['Reviews'] == df['Reviews'].max()][['App','Reviews']]
# Out:
#                          App Reviews
# 2989  GollerCepte Live Score    9992

# %%
df.sort_values(by='Reviews',ascending=False).head(1)
# Out:
#                          App Category Rating Reviews        Size  Installs  \
# 2989  GollerCepte Live Score   Sports    4.2    9992  32505856.0   1000000
#
#       Type  Price Content Rating  Genres  Last Updated Current Ver Android Ver
# 2989  Free    0.0       Everyone  Sports  May 23, 2018         6.5  4.1 and up

# %%
df.head()
# Out:
#                                                  App        Category Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  Art and design    4.1
# 1                                Coloring book moana  Art and design    3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  Art and design    4.7
# 3                              Sketch - Draw & Paint  Art and design    4.5
# 4              Pixel Draw - Number Art Coloring Book  Art and design    4.3
#
#   Reviews        Size  Installs  Type  Price Content Rating  \
# 0     159  19922944.0     10000  Free    0.0       Everyone
# 1     967  14680064.0    500000  Free    0.0       Everyone
# 2   87510   9122611.2   5000000  Free    0.0       Everyone
# 3  215644  26214400.0  50000000  Free    0.0           Teen
# 4     967   2936012.8    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df['Reviews'] = pd.to_numeric(df['Reviews'])

# %%
df['Category'].value_counts().head(1)
# Out:
# Category
# Family    1968
# Name: count, dtype: int64
